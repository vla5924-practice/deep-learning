# %% [markdown]
# # Глубокое обучение. Лабораторная работа №1
#
# Конфигурация нейронной сети:
#
# 1. Входной слой содержит `w x h` нейронов, что соответствует разрешению одноканального изображения (для изображений в базе MNIST составляет 28x28).
# 2. Выходной слой содержит `k` нейронов, что соответствует количеству классов изображений (для задачи классификации рукописных цифр MNIST – 10 классов).
# 3. Скрытый слой содержит `s` нейронов (параметр).
# 4. Скорость обучения (learning rate), размер пачки данных (batch size), количество эпох являются параметрами метода обучения.
# 5. В качестве функции активации на скрытом слое используется функция ReLU. В качестве функции активации на выходном слое используется функция softmax. Входной слой не содержит функцию активации.
# 6. В качестве функции ошибки используется кросс-энтропия. Функция активации softmax вместе с функцией ошибки кросс-энтропия упрощают вывод формул.
# 7. Набор параметров для демонстрации работы нейронной сети (и выложенные материалы и демонстрации в т/к выполняется на данных параметрах):
#     - Размер пачки может меняться от 8 до 64 изображений (в зависимости от доступного объема памяти).
#     - Скорость обучения - 0.1.
#     - Количество скрытых нейронов `s` - 300.
#     - Количество эпох – 20.

# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import struct
import tabulate
from array import array
from pathlib import Path
from time import time
# %matplotlib inline

# %% [markdown]
# ## Подготовка данных
#
# В качестве входных данных используется датасет MNIST-784 в формате IDX с сайта https://www.kaggle.com/datasets/hojjatk/mnist-dataset

# %% [markdown]
# ### Загрузка данных
#
# Пример реализации загрузчика: https://www.kaggle.com/code/hojjatk/read-mnist-dataset

# %%
class MnistDataloader(object):
    def __init__(self, training_images_filepath,training_labels_filepath,
                 test_images_filepath, test_labels_filepath):
        self.training_images_filepath = training_images_filepath
        self.training_labels_filepath = training_labels_filepath
        self.test_images_filepath = test_images_filepath
        self.test_labels_filepath = test_labels_filepath

    def read_images_labels(self, images_filepath, labels_filepath):
        labels = []
        with open(labels_filepath, 'rb') as file:
            magic, size = struct.unpack(">II", file.read(8))
            if magic != 2049:
                raise ValueError('Magic number mismatch, expected 2049, got {}'.format(magic))
            labels = array("B", file.read())

        with open(images_filepath, 'rb') as file:
            magic, size, rows, cols = struct.unpack(">IIII", file.read(16))
            if magic != 2051:
                raise ValueError('Magic number mismatch, expected 2051, got {}'.format(magic))
            image_data = array("B", file.read())
        images = []
        for i in range(size):
            images.append([0] * rows * cols)
        for i in range(size):
            images[i] = np.array(image_data[i * rows * cols:(i + 1) * rows * cols])

        return images, labels

    def load_data(self):
        x_train, y_train = self.read_images_labels(self.training_images_filepath, self.training_labels_filepath)
        x_test, y_test = self.read_images_labels(self.test_images_filepath, self.test_labels_filepath)
        return (x_train, y_train),(x_test, y_test)

# %%
input_path = Path("/work") / "mnist"
training_images_filepath = input_path / "train-images-idx3-ubyte/train-images-idx3-ubyte"
training_labels_filepath = input_path / "train-labels-idx1-ubyte/train-labels-idx1-ubyte"
test_images_filepath = input_path / "t10k-images-idx3-ubyte/t10k-images-idx3-ubyte"
test_labels_filepath = input_path / "t10k-labels-idx1-ubyte/t10k-labels-idx1-ubyte"

loader = MnistDataloader(training_images_filepath, training_labels_filepath, test_images_filepath, test_labels_filepath)
(X_train, y_train), (X_test, y_test) = loader.load_data()

# %% [markdown]
# ### Визуальная верификация
#
# Визуализация случайных 10 изображений в тренировочной выборке и 5 изображений в тестовой выборке

# %%
def show_images(images, title_texts):
    cols = 5
    rows = int(len(images)/cols) + 1
    plt.figure(figsize=(30,20))
    index = 1
    for image, title_text in zip(images, title_texts):
        plt.subplot(rows, cols, index)
        plt.imshow(image.reshape(28, 28), cmap=getattr(plt.cm, "gray", None))
        if (title_text != ''):
            plt.title(title_text, fontsize = 15)
        index += 1

images_2_show = []
titles_2_show = []
for i in range(0, 10):
    r = random.randint(1, 60000)
    images_2_show.append(X_train[r])
    titles_2_show.append('training image [' + str(r) + '] = ' + str(y_train[r]))

for i in range(0, 5):
    r = random.randint(1, 10000)
    images_2_show.append(X_test[r])
    titles_2_show.append('test image [' + str(r) + '] = ' + str(y_test[r]))

show_images(images_2_show, titles_2_show)

# %% [markdown]
# ### Нормализация данных
#
# Конвертация данных в формат float64 и выполнение one-hot encoding для целевого признака.

# %%
def one_hot_encode(arr):
    classes = np.unique(arr)
    n_classes = len(classes)
    one_hot = np.zeros((arr.size, n_classes), dtype=np.float64)
    for index, value in enumerate(arr):
        class_index = np.where(classes == value)[0][0]
        one_hot[index, class_index] = 1.0
    return one_hot

X_train = np.array(X_train, dtype=np.float64) / 255.0
X_test = np.array(X_test, dtype=np.float64) / 255.0
y_train = one_hot_encode(np.array(y_train, dtype=int))
y_test = one_hot_encode(np.array(y_test, dtype=int))

tab_columns = ("Входные параметры", "Целевой признак")
tab_data = [
    ("Размер обучающей выборки", str(X_train.shape), str(y_train.shape)),
    ("Размер тестовой выборки", str(X_test.shape), str(y_test.shape)),
]
print(tabulate.tabulate(tab_data, tab_columns, tablefmt="pipe"))
# Out:
# |                          | Входные параметры   | Целевой признак   |
# |:-------------------------|:--------------------|:------------------|
# | Размер обучающей выборки | (60000, 784)        | (60000, 10)       |
# | Размер тестовой выборки  | (10000, 784)        | (10000, 10)       |

# %%
def show_image_norm(X, y, idx):
    img = X[idx].reshape(28, 28)
    plt.imshow(img, cmap="gray")
    plt.title(np.argmax(y[idx]))
    plt.show()
    
show_image_norm(X_train, y_train, 0)

# %% [markdown]
# ## Реализация нейросети

# %% [markdown]
# ### Инициализация параметров
#
# Для сумматоров веса иницализируются случайными значениями, смещения иницализируются нулями.

# %%
def initialize_parameters(input_size, hidden_size, output_size):
    W1 = np.random.randn(input_size, hidden_size) * 0.01  # (784, 300)
    b1 = np.zeros((1, hidden_size))  # (1, 300)
    
    W2 = np.random.randn(hidden_size, output_size) * 0.01  # (300, 10)
    b2 = np.zeros((1, output_size))  # (1, 10)
    
    return W1, b1, W2, b2

# %% [markdown]
# Обновление параметров происходит с использованием градиентного спуска.

# %%
def update_parameters(W1, b1, W2, b2, dW1, db1, dW2, db2, learning_rate):
    W1 -= learning_rate * dW1
    b1 -= learning_rate * db1
    W2 -= learning_rate * dW2
    b2 -= learning_rate * db2
    return W1, b1, W2, b2

# %% [markdown]
# ### Вспомогательные функции
#
# Математические функции, используемые при реализации модели.

# %%
# ReLU activation function
def relu(Z):
    return np.maximum(0, Z)

# Derivative of ReLU
def relu_derivative(Z):
    return Z > 0

# Softmax activation function
def softmax(Z):
    expZ = np.exp(Z - np.max(Z, axis=1, keepdims=True))
    return expZ / expZ.sum(axis=1, keepdims=True)

# Cross-Entropy Loss
def compute_loss(y_true, y_pred):
    m = y_true.shape[0]
    return -np.sum(y_true * np.log(y_pred + 1e-9)) / m

# %% [markdown]
# ### Прямой проход
#
# Реализация прямого прохода для одной "пачки данных" (batch).

# %%
def forward_propagation(X, W1, b1, W2, b2):
    Z1 = X.dot(W1) + b1  # Hidden layer input
    A1 = relu(Z1)        # Hidden layer activation
    Z2 = A1.dot(W2) + b2 # Output layer input
    A2 = softmax(Z2)     # Output layer activation
    return Z1, A1, Z2, A2

# %% [markdown]
# ### Обратный проход
#
# Реализация обратного прохода для вычисления градиентов.

# %%
def backward_propagation(X, y_true, Z1, A1, Z2, A2, W2):
    m = y_true.shape[0]
    dZ2 = A2 - y_true               # dL_dZ2 (output layer gradient)
    # Z2.shape == (m, 10)
    dW2 = (A1.T).dot(dZ2) / m       # W2 gradient
    # W2.shape == (300, 10)
    db2 = np.sum(dZ2, axis=0, keepdims=True) / m  # b2 gradient
    # db2.shape == (1, 10)
    dA1 = dZ2.dot(W2.T)              # gradient x hidden layer
    # dA1.shape == (m, 300)
    dZ1 = dA1 * relu_derivative(Z1)  # dL_dZ1 (hidden layer gradient)
    # dZ1.shape == (m, 300)
    dW1 = (X.T).dot(dZ1) / m         # W1 gradient
    # dW1.shape == (784, 300)
    db1 = np.sum(dZ1, axis=0, keepdims=True) / m  # b1 gradient
    # db1.shape == (1, 300)
    return dW1, db1, dW2, db2

# %% [markdown]
# ## Обучение модели

# %% [markdown]
# ### Реализация обучения
#
# В качестве функции ошибки используется кросс-энтропия.

# %%
def train(X_train, y_train, X_test, y_test, learning_rate, batch_size, epochs, input_size, hidden_size, output_size):
    W1, b1, W2, b2 = initialize_parameters(input_size, hidden_size, output_size)

    for epoch in range(epochs):
        # Случайное перемешивание тренировочных данных
        permutation = np.random.permutation(X_train.shape[0])
        X_train_shuffled = X_train[permutation]
        y_train_shuffled = y_train[permutation]
        start_time = time()

        # Обучение по "пачкам данных" (batches)
        for i in range(0, X_train.shape[0], batch_size):
            X_batch = X_train_shuffled[i:i+batch_size]
            y_batch = y_train_shuffled[i:i+batch_size]
            Z1, A1, Z2, A2 = forward_propagation(X_batch, W1, b1, W2, b2)
            # Вывод ошибки раз в несколько итераций
            if i % 1000 == 0:
                loss = compute_loss(y_batch, A2)
                print(f"⌛ Epoch {epoch+1}: Batch {i}, Loss: {loss:.4f}")
            dW1, db1, dW2, db2 = backward_propagation(X_batch, y_batch, Z1, A1, Z2, A2, W2)
            W1, b1, W2, b2 = update_parameters(W1, b1, W2, b2, dW1, db1, dW2, db2, learning_rate)

        _, _, _, A2_train = forward_propagation(X_train, W1, b1, W2, b2)
        train_accuracy = np.mean(np.argmax(A2_train, axis=1) == np.argmax(y_train, axis=1))
        end_time = time()
        print(f"✅ Epoch {epoch+1}: Elapsed {end_time - start_time:.2f} seconds, Train accuracy: {train_accuracy:.4f}")

    _, _, _, A2_test = forward_propagation(X_test, W1, b1, W2, b2)
    test_accuracy = np.mean(np.argmax(A2_test, axis=1) == np.argmax(y_test, axis=1))
    print(f"Test accuracy: {test_accuracy:.4f}")

    return W1, b1, W2, b2

# %% [markdown]
# ### Запуск тренировки
#
# Параметры в текущем запуске:
#
# * размер входного слоя - 784
# * размер скрытого слоя - 300
# * размер выходного слоя - 10
# * скорость обучения - 0.1
# * размер "пачки данных" (batch) - 32
# * количество эпох - 20

# %%
input_size = 784  # 28x28 pixels
hidden_size = 300
output_size = 10
learning_rate = 0.1
batch_size = 32
epochs = 20

trained_params = train(X_train, y_train, X_test, y_test, learning_rate, batch_size, epochs, input_size, hidden_size, output_size)
# Out:
# ⌛ Epoch 1: Batch 0, Loss: 2.3025
# ⌛ Epoch 1: Batch 4000, Loss: 0.6143
# ⌛ Epoch 1: Batch 8000, Loss: 0.3443
# ⌛ Epoch 1: Batch 12000, Loss: 0.3252
# ⌛ Epoch 1: Batch 16000, Loss: 0.6313
# ⌛ Epoch 1: Batch 20000, Loss: 0.2069
# ⌛ Epoch 1: Batch 24000, Loss: 0.4840
# ⌛ Epoch 1: Batch 28000, Loss: 0.4964
# ⌛ Epoch 1: Batch 32000, Loss: 0.3122
# ⌛ Epoch 1: Batch 36000, Loss: 0.9736
# ⌛ Epoch 1: Batch 40000, Loss: 0.1865
# ⌛ Epoch 1: Batch 44000, Loss: 0.4885
# ⌛ Epoch 1: Batch 48000, Loss: 0.1405
# ⌛ Epoch 1: Batch 52000, Loss: 0.3285
# ⌛ Epoch 1: Batch 56000, Loss: 0.0902
# ✅ Epoch 1: Elapsed 5.68 seconds, Train accuracy: 0.9446
# ⌛ Epoch 2: Batch 0, Loss: 0.2385
# ⌛ Epoch 2: Batch 4000, Loss: 0.0800
# ⌛ Epoch 2: Batch 8000, Loss: 0.0564
# ⌛ Epoch 2: Batch 12000, Loss: 0.1254
# ⌛ Epoch 2: Batch 16000, Loss: 0.1721
# ⌛ Epoch 2: Batch 20000, Loss: 0.1637
# ⌛ Epoch 2: Batch 24000, Loss: 0.2385
# ⌛ Epoch 2: Batch 28000, Loss: 0.1516
# ⌛ Epoch 2: Batch 32000, Loss: 0.1589
# ⌛ Epoch 2: Batch 36000, Loss: 0.2302
# ⌛ Epoch 2: Batch 40000, Loss: 0.1262
# ⌛ Epoch 2: Batch 44000, Loss: 0.0953
# ⌛ Epoch 2: Batch 48000, Loss: 0.4018
# ⌛ Epoch 2: Batch 52000, Loss: 0.0808
# ⌛ Epoch 2: Batch 56000, Loss: 0.0456
# ✅ Epoch 2: Elapsed 5.21 seconds, Train accuracy: 0.9654
# ⌛ Epoch 3: Batch 0, Loss: 0.1001
# ⌛ Epoch 3: Batch 4000, Loss: 0.2115
# ⌛ Epoch 3: Batch 8000, Loss: 0.3078
# ⌛ Epoch 3: Batch 12000, Loss: 0.1047
# ⌛ Epoch 3: Batch 16000, Loss: 0.0731
# ⌛ Epoch 3: Batch 20000, Loss: 0.0382
# ⌛ Epoch 3: Batch 24000, Loss: 0.1525
# ⌛ Epoch 3: Batch 28000, Loss: 0.1110
# ⌛ Epoch 3: Batch 32000, Loss: 0.0937
# ⌛ Epoch 3: Batch 36000, Loss: 0.1294
# ⌛ Epoch 3: Batch 40000, Loss: 0.1256
# ⌛ Epoch 3: Batch 44000, Loss: 0.1386
# ⌛ Epoch 3: Batch 48000, Loss: 0.1059
# ⌛ Epoch 3: Batch 52000, Loss: 0.1290
# ⌛ Epoch 3: Batch 56000, Loss: 0.0640
# ✅ Epoch 3: Elapsed 5.19 seconds, Train accuracy: 0.9746
# ⌛ Epoch 4: Batch 0, Loss: 0.0947
# ⌛ Epoch 4: Batch 4000, Loss: 0.0217
# ⌛ Epoch 4: Batch 8000, Loss: 0.0662
# ⌛ Epoch 4: Batch 12000, Loss: 0.2546
# ⌛ Epoch 4: Batch 16000, Loss: 0.0980
# ⌛ Epoch 4: Batch 20000, Loss: 0.1117
# ⌛ Epoch 4: Batch 24000, Loss: 0.0415
# ⌛ Epoch 4: Batch 28000, Loss: 0.2789
# ⌛ Epoch 4: Batch 32000, Loss: 0.0238
# ⌛ Epoch 4: Batch 36000, Loss: 0.0489
# ⌛ Epoch 4: Batch 40000, Loss: 0.0070
# ⌛ Epoch 4: Batch 44000, Loss: 0.0331
# ⌛ Epoch 4: Batch 48000, Loss: 0.1380
# ⌛ Epoch 4: Batch 52000, Loss: 0.0350
# ⌛ Epoch 4: Batch 56000, Loss: 0.0613
# ✅ Epoch 4: Elapsed 5.15 seconds, Train accuracy: 0.9810
# ⌛ Epoch 5: Batch 0, Loss: 0.0288
# ⌛ Epoch 5: Batch 4000, Loss: 0.0494
# ⌛ Epoch 5: Batch 8000, Loss: 0.1218
# ⌛ Epoch 5: Batch 12000, Loss: 0.0212
# ⌛ Epoch 5: Batch 16000, Loss: 0.0292
# ⌛ Epoch 5: Batch 20000, Loss: 0.0672
# ⌛ Epoch 5: Batch 24000, Loss: 0.0344
# ⌛ Epoch 5: Batch 28000, Loss: 0.0944
# ⌛ Epoch 5: Batch 32000, Loss: 0.0192
# ⌛ Epoch 5: Batch 36000, Loss: 0.1808
# ⌛ Epoch 5: Batch 40000, Loss: 0.0786
# ⌛ Epoch 5: Batch 44000, Loss: 0.0175
# ⌛ Epoch 5: Batch 48000, Loss: 0.0806
# ⌛ Epoch 5: Batch 52000, Loss: 0.0856
# ⌛ Epoch 5: Batch 56000, Loss: 0.0170
# ✅ Epoch 5: Elapsed 5.44 seconds, Train accuracy: 0.9832
# ⌛ Epoch 6: Batch 0, Loss: 0.1809
# ⌛ Epoch 6: Batch 4000, Loss: 0.0192
# ⌛ Epoch 6: Batch 8000, Loss: 0.0287
# ⌛ Epoch 6: Batch 12000, Loss: 0.0521
# ⌛ Epoch 6: Batch 16000, Loss: 0.0464
# ⌛ Epoch 6: Batch 20000, Loss: 0.0589
# ⌛ Epoch 6: Batch 24000, Loss: 0.1935
# ⌛ Epoch 6: Batch 28000, Loss: 0.0112
# ⌛ Epoch 6: Batch 32000, Loss: 0.2395
# ⌛ Epoch 6: Batch 36000, Loss: 0.0455
# ⌛ Epoch 6: Batch 40000, Loss: 0.1055
# ⌛ Epoch 6: Batch 44000, Loss: 0.0194
# ⌛ Epoch 6: Batch 48000, Loss: 0.0294
# ⌛ Epoch 6: Batch 52000, Loss: 0.0365
# ⌛ Epoch 6: Batch 56000, Loss: 0.0488
# ✅ Epoch 6: Elapsed 5.49 seconds, Train accuracy: 0.9859
# ⌛ Epoch 7: Batch 0, Loss: 0.0674
# ⌛ Epoch 7: Batch 4000, Loss: 0.0664
# ⌛ Epoch 7: Batch 8000, Loss: 0.0187
# ⌛ Epoch 7: Batch 12000, Loss: 0.0174
# ⌛ Epoch 7: Batch 16000, Loss: 0.0904
# ⌛ Epoch 7: Batch 20000, Loss: 0.0380
# ⌛ Epoch 7: Batch 24000, Loss: 0.0284
# ⌛ Epoch 7: Batch 28000, Loss: 0.0306
# ⌛ Epoch 7: Batch 32000, Loss: 0.0284
# ⌛ Epoch 7: Batch 36000, Loss: 0.0050
# ⌛ Epoch 7: Batch 40000, Loss: 0.0525
# ⌛ Epoch 7: Batch 44000, Loss: 0.1587
# ⌛ Epoch 7: Batch 48000, Loss: 0.1989
# ⌛ Epoch 7: Batch 52000, Loss: 0.0363
# ⌛ Epoch 7: Batch 56000, Loss: 0.0253
# ✅ Epoch 7: Elapsed 5.18 seconds, Train accuracy: 0.9909
# ⌛ Epoch 8: Batch 0, Loss: 0.0168
# ⌛ Epoch 8: Batch 4000, Loss: 0.0095
# ⌛ Epoch 8: Batch 8000, Loss: 0.0075
# ⌛ Epoch 8: Batch 12000, Loss: 0.0222
# ⌛ Epoch 8: Batch 16000, Loss: 0.0452
# ⌛ Epoch 8: Batch 20000, Loss: 0.0099
# ⌛ Epoch 8: Batch 24000, Loss: 0.1050
# ⌛ Epoch 8: Batch 28000, Loss: 0.0238
# ⌛ Epoch 8: Batch 32000, Loss: 0.0667
# ⌛ Epoch 8: Batch 36000, Loss: 0.0117
# ⌛ Epoch 8: Batch 40000, Loss: 0.0215
# ⌛ Epoch 8: Batch 44000, Loss: 0.2057
# ⌛ Epoch 8: Batch 48000, Loss: 0.0107
# ⌛ Epoch 8: Batch 52000, Loss: 0.0233
# ⌛ Epoch 8: Batch 56000, Loss: 0.0327
# ✅ Epoch 8: Elapsed 5.19 seconds, Train accuracy: 0.9920
# ⌛ Epoch 9: Batch 0, Loss: 0.0101
# ⌛ Epoch 9: Batch 4000, Loss: 0.0645
# ⌛ Epoch 9: Batch 8000, Loss: 0.0135
# ⌛ Epoch 9: Batch 12000, Loss: 0.0370
# ⌛ Epoch 9: Batch 16000, Loss: 0.0046
# ⌛ Epoch 9: Batch 20000, Loss: 0.0138
# ⌛ Epoch 9: Batch 24000, Loss: 0.0719
# ⌛ Epoch 9: Batch 28000, Loss: 0.0198
# ⌛ Epoch 9: Batch 32000, Loss: 0.0170
# ⌛ Epoch 9: Batch 36000, Loss: 0.0172
# ⌛ Epoch 9: Batch 40000, Loss: 0.0035
# ⌛ Epoch 9: Batch 44000, Loss: 0.1599
# ⌛ Epoch 9: Batch 48000, Loss: 0.0171
# ⌛ Epoch 9: Batch 52000, Loss: 0.0155
# ⌛ Epoch 9: Batch 56000, Loss: 0.0266
# ✅ Epoch 9: Elapsed 5.11 seconds, Train accuracy: 0.9937
# ⌛ Epoch 10: Batch 0, Loss: 0.0053
# ⌛ Epoch 10: Batch 4000, Loss: 0.0126
# ⌛ Epoch 10: Batch 8000, Loss: 0.0198
# ⌛ Epoch 10: Batch 12000, Loss: 0.0368
# ⌛ Epoch 10: Batch 16000, Loss: 0.0279
# ⌛ Epoch 10: Batch 20000, Loss: 0.0042
# ⌛ Epoch 10: Batch 24000, Loss: 0.0085
# ⌛ Epoch 10: Batch 28000, Loss: 0.0850
# ⌛ Epoch 10: Batch 32000, Loss: 0.1114
# ⌛ Epoch 10: Batch 36000, Loss: 0.0563
# ⌛ Epoch 10: Batch 40000, Loss: 0.0125
# ⌛ Epoch 10: Batch 44000, Loss: 0.0341
# ⌛ Epoch 10: Batch 48000, Loss: 0.0023
# ⌛ Epoch 10: Batch 52000, Loss: 0.0092
# ⌛ Epoch 10: Batch 56000, Loss: 0.0216
# ✅ Epoch 10: Elapsed 5.17 seconds, Train accuracy: 0.9953
# ⌛ Epoch 11: Batch 0, Loss: 0.0157
# ⌛ Epoch 11: Batch 4000, Loss: 0.0155
# ⌛ Epoch 11: Batch 8000, Loss: 0.1010
# ⌛ Epoch 11: Batch 12000, Loss: 0.0220
# ⌛ Epoch 11: Batch 16000, Loss: 0.0042
# ⌛ Epoch 11: Batch 20000, Loss: 0.0256
# ⌛ Epoch 11: Batch 24000, Loss: 0.0020
# ⌛ Epoch 11: Batch 28000, Loss: 0.0071
# ⌛ Epoch 11: Batch 32000, Loss: 0.0798
# ⌛ Epoch 11: Batch 36000, Loss: 0.0025
# ⌛ Epoch 11: Batch 40000, Loss: 0.0319
# ⌛ Epoch 11: Batch 44000, Loss: 0.0049
# ⌛ Epoch 11: Batch 48000, Loss: 0.0163
# ⌛ Epoch 11: Batch 52000, Loss: 0.0011
# ⌛ Epoch 11: Batch 56000, Loss: 0.0050
# ✅ Epoch 11: Elapsed 5.06 seconds, Train accuracy: 0.9944
# ⌛ Epoch 12: Batch 0, Loss: 0.0473
# ⌛ Epoch 12: Batch 4000, Loss: 0.0558
# ⌛ Epoch 12: Batch 8000, Loss: 0.1443
# ⌛ Epoch 12: Batch 12000, Loss: 0.1856
# ⌛ Epoch 12: Batch 16000, Loss: 0.0032
# ⌛ Epoch 12: Batch 20000, Loss: 0.0056
# ⌛ Epoch 12: Batch 24000, Loss: 0.0842
# ⌛ Epoch 12: Batch 28000, Loss: 0.0082
# ⌛ Epoch 12: Batch 32000, Loss: 0.0121
# ⌛ Epoch 12: Batch 36000, Loss: 0.0358
# ⌛ Epoch 12: Batch 40000, Loss: 0.0013
# ⌛ Epoch 12: Batch 44000, Loss: 0.0023
# ⌛ Epoch 12: Batch 48000, Loss: 0.0231
# ⌛ Epoch 12: Batch 52000, Loss: 0.0031
# ⌛ Epoch 12: Batch 56000, Loss: 0.0031
# ✅ Epoch 12: Elapsed 5.21 seconds, Train accuracy: 0.9966
# ⌛ Epoch 13: Batch 0, Loss: 0.0059
# ⌛ Epoch 13: Batch 4000, Loss: 0.0148
# ⌛ Epoch 13: Batch 8000, Loss: 0.0187
# ⌛ Epoch 13: Batch 12000, Loss: 0.1332
# ⌛ Epoch 13: Batch 16000, Loss: 0.0076
# ⌛ Epoch 13: Batch 20000, Loss: 0.0008
# ⌛ Epoch 13: Batch 24000, Loss: 0.0105
# ⌛ Epoch 13: Batch 28000, Loss: 0.0033
# ⌛ Epoch 13: Batch 32000, Loss: 0.0030
# ⌛ Epoch 13: Batch 36000, Loss: 0.0109
# ⌛ Epoch 13: Batch 40000, Loss: 0.0097
# ⌛ Epoch 13: Batch 44000, Loss: 0.0059
# ⌛ Epoch 13: Batch 48000, Loss: 0.0312
# ⌛ Epoch 13: Batch 52000, Loss: 0.0107
# ⌛ Epoch 13: Batch 56000, Loss: 0.0037
# ✅ Epoch 13: Elapsed 5.15 seconds, Train accuracy: 0.9974
# ⌛ Epoch 14: Batch 0, Loss: 0.0126
# ⌛ Epoch 14: Batch 4000, Loss: 0.0072
# ⌛ Epoch 14: Batch 8000, Loss: 0.0072
# ⌛ Epoch 14: Batch 12000, Loss: 0.0380
# ⌛ Epoch 14: Batch 16000, Loss: 0.0164
# ⌛ Epoch 14: Batch 20000, Loss: 0.0067
# ⌛ Epoch 14: Batch 24000, Loss: 0.0119
# ⌛ Epoch 14: Batch 28000, Loss: 0.0072
# ⌛ Epoch 14: Batch 32000, Loss: 0.0191
# ⌛ Epoch 14: Batch 36000, Loss: 0.0130
# ⌛ Epoch 14: Batch 40000, Loss: 0.0085
# ⌛ Epoch 14: Batch 44000, Loss: 0.0055
# ⌛ Epoch 14: Batch 48000, Loss: 0.0054
# ⌛ Epoch 14: Batch 52000, Loss: 0.0079
# ⌛ Epoch 14: Batch 56000, Loss: 0.0049
# ✅ Epoch 14: Elapsed 5.25 seconds, Train accuracy: 0.9971
# ⌛ Epoch 15: Batch 0, Loss: 0.0056
# ⌛ Epoch 15: Batch 4000, Loss: 0.0500
# ⌛ Epoch 15: Batch 8000, Loss: 0.0049
# ⌛ Epoch 15: Batch 12000, Loss: 0.0097
# ⌛ Epoch 15: Batch 16000, Loss: 0.0111
# ⌛ Epoch 15: Batch 20000, Loss: 0.0408
# ⌛ Epoch 15: Batch 24000, Loss: 0.0037
# ⌛ Epoch 15: Batch 28000, Loss: 0.0185
# ⌛ Epoch 15: Batch 32000, Loss: 0.0070
# ⌛ Epoch 15: Batch 36000, Loss: 0.0123
# ⌛ Epoch 15: Batch 40000, Loss: 0.0424
# ⌛ Epoch 15: Batch 44000, Loss: 0.0027
# ⌛ Epoch 15: Batch 48000, Loss: 0.0099
# ⌛ Epoch 15: Batch 52000, Loss: 0.0104
# ⌛ Epoch 15: Batch 56000, Loss: 0.0106
# ✅ Epoch 15: Elapsed 5.15 seconds, Train accuracy: 0.9988
# ⌛ Epoch 16: Batch 0, Loss: 0.0388
# ⌛ Epoch 16: Batch 4000, Loss: 0.0005
# ⌛ Epoch 16: Batch 8000, Loss: 0.0060
# ⌛ Epoch 16: Batch 12000, Loss: 0.0009
# ⌛ Epoch 16: Batch 16000, Loss: 0.0031
# ⌛ Epoch 16: Batch 20000, Loss: 0.0418
# ⌛ Epoch 16: Batch 24000, Loss: 0.0009
# ⌛ Epoch 16: Batch 28000, Loss: 0.0040
# ⌛ Epoch 16: Batch 32000, Loss: 0.0012
# ⌛ Epoch 16: Batch 36000, Loss: 0.0036
# ⌛ Epoch 16: Batch 40000, Loss: 0.0010
# ⌛ Epoch 16: Batch 44000, Loss: 0.0034
# ⌛ Epoch 16: Batch 48000, Loss: 0.0019
# ⌛ Epoch 16: Batch 52000, Loss: 0.0249
# ⌛ Epoch 16: Batch 56000, Loss: 0.0329
# ✅ Epoch 16: Elapsed 5.16 seconds, Train accuracy: 0.9990
# ⌛ Epoch 17: Batch 0, Loss: 0.0143
# ⌛ Epoch 17: Batch 4000, Loss: 0.0011
# ⌛ Epoch 17: Batch 8000, Loss: 0.0041
# ⌛ Epoch 17: Batch 12000, Loss: 0.1142
# ⌛ Epoch 17: Batch 16000, Loss: 0.0115
# ⌛ Epoch 17: Batch 20000, Loss: 0.0052
# ⌛ Epoch 17: Batch 24000, Loss: 0.0283
# ⌛ Epoch 17: Batch 28000, Loss: 0.0017
# ⌛ Epoch 17: Batch 32000, Loss: 0.0020
# ⌛ Epoch 17: Batch 36000, Loss: 0.0096
# ⌛ Epoch 17: Batch 40000, Loss: 0.0133
# ⌛ Epoch 17: Batch 44000, Loss: 0.0022
# ⌛ Epoch 17: Batch 48000, Loss: 0.0318
# ⌛ Epoch 17: Batch 52000, Loss: 0.0068
# ⌛ Epoch 17: Batch 56000, Loss: 0.0139
# ✅ Epoch 17: Elapsed 5.15 seconds, Train accuracy: 0.9992
# ⌛ Epoch 18: Batch 0, Loss: 0.0265
# ⌛ Epoch 18: Batch 4000, Loss: 0.0477
# ⌛ Epoch 18: Batch 8000, Loss: 0.0054
# ⌛ Epoch 18: Batch 12000, Loss: 0.0146
# ⌛ Epoch 18: Batch 16000, Loss: 0.0082
# ⌛ Epoch 18: Batch 20000, Loss: 0.0108
# ⌛ Epoch 18: Batch 24000, Loss: 0.0056
# ⌛ Epoch 18: Batch 28000, Loss: 0.0096
# ⌛ Epoch 18: Batch 32000, Loss: 0.0223
# ⌛ Epoch 18: Batch 36000, Loss: 0.0023
# ⌛ Epoch 18: Batch 40000, Loss: 0.0088
# ⌛ Epoch 18: Batch 44000, Loss: 0.0292
# ⌛ Epoch 18: Batch 48000, Loss: 0.0284
# ⌛ Epoch 18: Batch 52000, Loss: 0.0138
# ⌛ Epoch 18: Batch 56000, Loss: 0.0229
# ✅ Epoch 18: Elapsed 5.17 seconds, Train accuracy: 0.9995
# ⌛ Epoch 19: Batch 0, Loss: 0.0050
# ⌛ Epoch 19: Batch 4000, Loss: 0.0032
# ⌛ Epoch 19: Batch 8000, Loss: 0.0340
# ⌛ Epoch 19: Batch 12000, Loss: 0.0029
# ⌛ Epoch 19: Batch 16000, Loss: 0.0115
# ⌛ Epoch 19: Batch 20000, Loss: 0.0085
# ⌛ Epoch 19: Batch 24000, Loss: 0.0101
# ⌛ Epoch 19: Batch 28000, Loss: 0.0031
# ⌛ Epoch 19: Batch 32000, Loss: 0.0041
# ⌛ Epoch 19: Batch 36000, Loss: 0.0045
# ⌛ Epoch 19: Batch 40000, Loss: 0.0067
# ⌛ Epoch 19: Batch 44000, Loss: 0.0051
# ⌛ Epoch 19: Batch 48000, Loss: 0.0010
# ⌛ Epoch 19: Batch 52000, Loss: 0.0068
# ⌛ Epoch 19: Batch 56000, Loss: 0.0134
# ✅ Epoch 19: Elapsed 5.14 seconds, Train accuracy: 0.9996
# ⌛ Epoch 20: Batch 0, Loss: 0.0041
# ⌛ Epoch 20: Batch 4000, Loss: 0.0029
# ⌛ Epoch 20: Batch 8000, Loss: 0.0025
# ⌛ Epoch 20: Batch 12000, Loss: 0.0027
# ⌛ Epoch 20: Batch 16000, Loss: 0.0056
# ⌛ Epoch 20: Batch 20000, Loss: 0.0087
# ⌛ Epoch 20: Batch 24000, Loss: 0.0050
# ⌛ Epoch 20: Batch 28000, Loss: 0.0128
# ⌛ Epoch 20: Batch 32000, Loss: 0.0031
# ⌛ Epoch 20: Batch 36000, Loss: 0.0011
# ⌛ Epoch 20: Batch 40000, Loss: 0.0066
# ⌛ Epoch 20: Batch 44000, Loss: 0.0007
# ⌛ Epoch 20: Batch 48000, Loss: 0.0059
# ⌛ Epoch 20: Batch 52000, Loss: 0.0041
# ⌛ Epoch 20: Batch 56000, Loss: 0.0034
# ✅ Epoch 20: Elapsed 5.24 seconds, Train accuracy: 0.9997
# Test accuracy: 0.9813

# %% [markdown]
# ### Результаты
#
# Точность на тестовой выборке: более 99%
#
# Точность на тренировочной выборке: более 98%
#
# > Время обучения на конфигурации 2 CPUs, 5 GB RAM: примерно 4 минуты
